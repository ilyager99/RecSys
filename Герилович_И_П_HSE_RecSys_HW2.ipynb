# %% [markdown]
# ## ДЗ №2. Матричные факторизации

# %% [markdown]
# #### В этой домашке вам предстоит реализовать некоторые базовые модели матричной факторизации
#
# #### Дата выдачи: 17.02.25
#
# #### Мягкий дедлайн: 02.03.25 23:59 MSK
#
# #### Жесткий дедлайн: 09.03.25 23:59 MSK

# %% [markdown]
# В этом задании мы будем работать с классическим для рекоендательных систем датасетом [MovieLens 1M](https://grouplens.org/datasets/movielens/1m/). Датасет содержит рейтинги оценки для 4000 фильмов от 6000 пользователей. Более подробное описание можете найти на странице с датасетом и в README файле

# %%
# !pip install implicit
# Out:
# Requirement already satisfied: implicit in /usr/local/lib/python3.11/dist-packages (0.7.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from implicit) (1.26.4)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.11/dist-packages (from implicit) (1.13.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from implicit) (4.67.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from implicit) (3.5.0)

# %%
# !wget https://files.grouplens.org/datasets/movielens/ml-1m.zip
# !unzip ml-1m.zip
# !cat ml-1m/README
# Out:
# --2025-03-02 17:00:29--  https://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917549 (5.6M) [application/zip]
# Saving to: ‘ml-1m.zip.2’
#
# ml-1m.zip.2         100%[===================>]   5.64M  11.7MB/s    in 0.5s
#
# 2025-03-02 17:00:29 (11.7 MB/s) - ‘ml-1m.zip.2’ saved [5917549/5917549]
#
# Archive:  ml-1m.zip
# replace ml-1m/movies.dat? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import numpy as np
from typing import Union

from scipy.sparse.linalg import svds
from scipy.sparse import issparse
import time
import matplotlib.pyplot as plt
from sklearn.metrics import ndcg_score


import numpy as np
from implicit.als import AlternatingLeastSquares

# %%
df = pd.read_csv("ml-1m/ratings.dat", sep='::', names=['user_id', 'item_id', 'rating', 'timestamp'], engine='python')
df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')
df.drop('timestamp', axis=1, inplace=True)
df.head()
# Out:
#    user_id  item_id  rating            datetime
# 0        1     1193       5 2000-12-31 22:12:40
# 1        1      661       3 2000-12-31 22:35:09
# 2        1      914       3 2000-12-31 22:32:48
# 3        1     3408       4 2000-12-31 22:04:35
# 4        1     2355       5 2001-01-06 23:38:11

# %%
value_counts = df['item_id'].value_counts()
filtered_values = value_counts[value_counts > 20].index
df = df[df['item_id'].isin(filtered_values)].copy()

# %%
train_end = '2000-12-01'
df_train = df[df['datetime'] < train_end].copy()
df_test = df[df['datetime'] >= train_end].copy()
df_train.shape, df_test.shape
# Out:
# ((787420, 4), (207432, 4))

# %%
train_users = df_train['user_id'].unique()
train_items = df_train['item_id'].unique()

df_test = df_test[df_test['user_id'].isin(train_users)]
df_test = df_test[df_test['item_id'].isin(train_items)]
df_test.shape
# Out:
# (106471, 4)

# %%
from sklearn.preprocessing import LabelEncoder

user_le = LabelEncoder()
item_le = LabelEncoder()

df_train['user_id'] = user_le.fit_transform(df_train['user_id'])
df_train['item_id'] = item_le.fit_transform(df_train['item_id'])

df_test['user_id'] = user_le.transform(df_test['user_id'])
df_test['item_id'] = item_le.transform(df_test['item_id'])

# %%
df_train['user_id'].nunique(), df_train['user_id'].max()
df_train['item_id'].nunique(), df_train['item_id'].max()
# Out:
# (3010, 3009)

# %% [markdown]
# ##### Задание 1. Напишем функцию, которая превратит датафрейм в матрицу интеракций. В функции df_to_matrix реализуйте функцию, которая принимает датафрейм и возвращает np.array матрицу интеракций. В функции df_to_coo реализуйте функцию, которая принимает датафрейм и возвращает разреженную матрицу интеракций в coo_array формате

# %%
def df_to_matrix(df: pd.DataFrame) -> np.ndarray:
  cnt_users = df['user_id'].nunique()
  cnt_item = df['item_id'].nunique()

  result = np.zeros((cnt_users, cnt_item))

  user_id = df['user_id'].values
  item_id = df['item_id'].values
  rating = df['rating'].values

  result[user_id, item_id] = rating

  return result

# %%
interactions = df_to_matrix(df_train)

# %%
from scipy.sparse import coo_array, csr_matrix

def df_to_coo(df: pd.DataFrame) -> coo_array:
  cnt_users = df['user_id'].nunique()
  cnt_item = df['item_id'].nunique()

  user_id = df['user_id'].values
  item_id = df['item_id'].values
  rating = df['rating'].values

  result = coo_array((rating, (user_id, item_id)), shape=(cnt_users, cnt_item))

  return result

# %%
coo_interactions = df_to_coo(df_train)

# %%
assert (interactions != 0).sum() == df_train.shape[0]
assert interactions[0, 2994] == 3
assert interactions[2369, 1203] == 5
assert interactions[1557, 459] == 3
assert np.allclose(coo_interactions.toarray(), interactions)

# %% [markdown]
# ##### Задание 2.1. Рассмотрим [SVD](https://en.wikipedia.org/wiki/Singular_value_decomposition). Возьмите готовую реализуцию алгоритма из numpy.linalg или из scipy.linalg и примените алгоритм к матрицам интеракций, полученным в первом задании. Для работы со sparse матрицей обычная реализация svd не подойдет и нужно будет воспользоваться scipy.sparse.linalg.svds. Вам нужно разложить матрицу интеракций на 3 матрицы U, S, V, а затем перемножить их и восстановить изначальную матрицу. При полном разложении исходная матрица должна восстанавливаться максимально хорошо

# %%
from scipy.sparse.linalg import svds

def make_svd(interactions: Union[np.ndarray, coo_array], n_singular_values: int = -1):
    if isinstance(interactions, coo_array):
        interactions = interactions.astype(float).tocsr()
        if n_singular_values == -1:
            n_singular_values = min(interactions.shape) - 1

        U, S, Vt = svds(interactions, k=n_singular_values)
        S = np.diag(S)

    elif isinstance(interactions, np.ndarray):
        interactions = interactions.astype(float)
        U, S, Vt = np.linalg.svd(interactions, full_matrices=False)

        if n_singular_values != -1:
            U = U[:, :n_singular_values]
            S = np.diag(S[:n_singular_values])
            Vt = Vt[:n_singular_values, :]
        else:
            S = np.diag(S)
    return U, S, Vt

# %%
U, S, V = make_svd(interactions)
assert np.allclose(U @ S @ V, interactions)

# %%
U1, S1, V1 = make_svd(interactions, 10)
U, S, V = make_svd(coo_interactions, 10)
assert np.allclose(U1 @ S1 @ V1, U @ S @ V)

# %% [markdown]
# ##### Задание 2.2. Теперь попробуем сделать рекомендации с помощью SVD. Мы научились восстанавливать исходную матрицу с помощью разложения, теперь же мы хотим порекомендовать пользователю айтемы, которые будут для него максимально релевантны(в восстановленной матрице у них будет самый высокий скор). Для каждого пользователя нужно будет найти индексы айтемов, которые имеют максимальный скор. При этом стоит обратить внимание, что мы не хотим рекомендовать пользователю айтемы, с которыми он уже взаимодействовал

# %%
def make_svd_recommendations(
    interactions: Union[np.ndarray, coo_array, csr_matrix],
    n_singular_values: int = -1,
    top_k: int = 100,
):

    if issparse(interactions):
        interactions = interactions.astype(float).toarray()

    U, S, Vt = np.linalg.svd(interactions, full_matrices=False)

    if n_singular_values != -1:
        U = U[:, :n_singular_values]
        S = np.diag(S[:n_singular_values])
        Vt = Vt[:n_singular_values, :]
    else:
        S = np.diag(S)

    predicted_scores = U @ S @ Vt

    known_interactions = interactions.astype(bool)
    predicted_scores[known_interactions] = -np.inf

    recommendations = np.argsort(-predicted_scores, axis=1)[:, :top_k]

    return recommendations

# %%
recs = make_svd_recommendations(interactions, -1, 100)
assert recs.shape == (interactions.shape[0], 100)

# %% [markdown]
# ##### Задание 2.3. Теперь давайте посмотрим как будет зависеть качетво рекомендаций, от количества сингулярных чисел, которые мы возьмем в SVD разложении. Переберите n_singular_values из списка [1, 10, 50, 200, 1000] и посмотрите как будет изменяться метрика NDCG на тестовом датасете для таких рекомендаций и как будет меняться время вычисления. Для каждого графики зависимости метрики NDCG от n_singular_values и времени работы алгоритма от n_singular_values(Время работы будет меняться только для sparse-матрицы, стоит запускать алгоритм именно для нее)

# %%
# Посчитаем NDCG
def calculate_ndcg(test_df, recommendations, top_k):
    ndcg_scores = []
    for user_id in range(recommendations.shape[0]):
        true_items = test_df[test_df['user_id'] == user_id]['item_id'].values
        if len(true_items) == 0:
            continue
        pred_items = recommendations[user_id]
        true_relevance = np.isin(pred_items, true_items).astype(int)
        ideal_relevance = np.sort(true_relevance)[::-1]
        ndcg_scores.append(ndcg_score([true_relevance], [ideal_relevance], k=top_k))
    return np.mean(ndcg_scores)

# %%
def plot_graphs(train_df: pd.DataFrame, test_df: pd.DataFrame, top_k: int = 100):
    n_singular_values_list = [1, 10, 50, 200, 1000]
    ndcg_scores = []
    execution_times = []

    all_items = pd.unique(pd.concat([train_df['item_id'], test_df['item_id']])).tolist()
    all_items.sort()

    interactions = train_df.pivot_table(index='user_id', columns='item_id', values='rating', fill_value=0)
    interactions = interactions.reindex(columns=all_items, fill_value=0).values

    for n_singular_values in n_singular_values_list:
        start_time = time.time()
        recommendations = make_svd_recommendations(interactions, n_singular_values, top_k)
        execution_time = time.time() - start_time
        execution_times.append(execution_time)

        ndcg = calculate_ndcg(test_df, recommendations, top_k)
        ndcg_scores.append(ndcg)

        print(f"n_singular_values: {n_singular_values}, NDCG: {ndcg}, Время: {execution_time}")

    plt.subplot(1, 2, 1)
    plt.plot(n_singular_values_list, ndcg_scores, marker='o', color='b')
    plt.xlabel('Число сингулярных значений')
    plt.ylabel('NDCG')
    plt.title('Зависимость NDCG от сингулярных значений')

    plt.subplot(1, 2, 2)
    plt.plot(n_singular_values_list, execution_times, marker='o', color='g')
    plt.xlabel('Число сингулярных значений')
    plt.ylabel('Время выполнения')
    plt.title('Зависимость времени сингулярных значений')

    plt.tight_layout()
    plt.show()

# %%
plot_graphs(df_train, df_test, top_k=100)
# Out:
# n_singular_values: 1, NDCG: 0.4828999441784038, Время: 52.932244300842285
# n_singular_values: 10, NDCG: 0.5145407168219976, Время: 53.528595209121704
# n_singular_values: 50, NDCG: 0.4983858489234908, Время: 53.18186593055725
# n_singular_values: 200, NDCG: 0.4431266724573158, Время: 53.63682460784912
# n_singular_values: 1000, NDCG: 0.2845740757963632, Время: 54.46471929550171

# %% [markdown]
# Оптимальное значение n_singular_values - 10, увеличение числа сингулярных компонент сверх этого значения ухудшает качество рекомендаций. Максимальное значение метрики достигается при небольшом значение сингулярных компомонент, это может быть связано с тем, что первые несколько сингулярных чисел обычно соответствуют наиболее значимым латентным факторам, которые объясняют основную информацию о предпочтениях пользователей.

# %% [markdown]
# ##### Задание 3.1. Перейдем к [ALS](http://yifanhu.net/PUB/cf.pdf). Возьмем реализацию iALS из библиотеки [implicit](https://benfred.github.io/implicit/api/models/cpu/als.html). Обучите ALS на нашем датасете, сделайте top_k рекомендации для юзеров из тестового датасета, и сравните метрики ALS с метриками, которые получились в SVD. Попробуйте перебрать гиперпараметры и найдите оптимальное число факторов, коэффициент alpha и коэффициент регуляризации.

# %%
def make_als_recommendations(
    interactions: Union[np.ndarray, coo_array],
    top_k: int = 100,
    n_factors: int = 100,
    alpha: float = 1.0,
    regularization: float = 0.01,
):
    if not isinstance(interactions, coo_array):
        interactions = coo_array(interactions)

    model = AlternatingLeastSquares(
        factors=n_factors,
        regularization=regularization,
        alpha=alpha,
        iterations=20,
        random_state=42,
    )
    model.fit(interactions)

    user_factors = model.user_factors
    item_factors = model.item_factors
    predicted_scores = user_factors @ item_factors.T

    known_interactions = interactions.astype(bool).toarray()
    predicted_scores[known_interactions] = -np.inf

    recommendations = np.argsort(-predicted_scores, axis=1)[:, :top_k]

    return recommendations, model

# %%
csr_interactions = csr_matrix(coo_interactions)

als_recommendations, als_model = make_als_recommendations(
    csr_interactions,
    top_k=100,
    n_factors=100,
    alpha=1.0,
    regularization=0.01,
)

svd_recommendations = make_svd_recommendations(
    csr_interactions,
    n_singular_values=10,
    top_k=100,
)

als_ndcg = calculate_ndcg(df_test, als_recommendations, top_k=100)
svd_ndcg = calculate_ndcg(df_test, svd_recommendations, top_k=100)

print(f"ALS NDCG: {als_ndcg}")
print(f"SVD NDCG: {svd_ndcg}")
# Out:
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.005728244781494141 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]
# ALS NDCG: 0.476916992285869
# SVD NDCG: 0.5145407168219976

# %% [markdown]
# Без подбора гип-ов SVD показал более высокое качество рекомендаций с метрикой NDCG ~ 0.52,  ALS показал результат хуже ~ 0.48.

# %%
recs, model = make_als_recommendations(interactions)
assert recs.shape == (interactions.shape[0], 100)
# Out:
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.00959634780883789 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ##### Задание 3.2. Сделайте объяснение рекомендаций для нескольких юзеров(als.explain). Воспользуйтесь файлом movies.dat чтобы перейти от индексов фильмов к их названием

# %%
movi_df = pd.read_csv("ml-1m/movies.dat", sep='::', engine='python', encoding="latin1", names=["MovieID", "Title", "Genres"])

# %%
movi_df.head(5)
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
movi_df.tail(5)
# Out:
#       MovieID                       Title          Genres
# 3878     3948     Meet the Parents (2000)          Comedy
# 3879     3949  Requiem for a Dream (2000)           Drama
# 3880     3950            Tigerland (2000)           Drama
# 3881     3951     Two Family House (2000)           Drama
# 3882     3952       Contender, The (2000)  Drama|Thriller

# %%
item_id_title = dict(zip(movi_df["MovieID"], movi_df["Title"]))

# %%
def explain_recommendations(user_ids, model, interactions, recommendations, item_id_title, top_k=5):

    for user_id in user_ids:
        print(f"Рекомендации для пользователя {user_id}:")
        user_recommendations = recommendations[user_id][:top_k]

        for item_id in user_recommendations:
            explanation = model.explain(user_id, interactions, item_id)

            item_title = item_id_title.get(item_id, "Неизвестный фильм")

            print(f"Фильм: {item_title} (ID: {item_id})")
            print("Фильмы, влияющие на рекомендацию:")

            for influenced_item_id, weight in explanation[1]:
                influenced_item_title = item_id_title.get(influenced_item_id, "Неизвестный фильм")
                print(f"  - {influenced_item_title} (ID: {influenced_item_id}, Вес: {weight:.4f})")

csr_interactions = csr_matrix(coo_interactions)
np.random.seed(42)
random_user_ids = np.random.choice(csr_interactions.shape[0], size=5, replace=False)

explain_recommendations(random_user_ids, model, csr_interactions, recs, item_id_title)
# Out:
# Рекомендации для пользователя 5062:
# Фильм: Неизвестный фильм (ID: 1691)
# Фильмы, влияющие на рекомендацию:
#   - In the Name of the Father (1993) (ID: 475, Вес: 0.0563)
#   - Men With Guns (1997) (ID: 1788, Вес: 0.0482)
#   - Turning, The (1992) (ID: 1524, Вес: 0.0479)
#   - Soul Man (1986) (ID: 2473, Вес: 0.0477)
#   - Father of the Bride Part II (1995) (ID: 5, Вес: 0.0440)
#   - Magic Hunter (1994) (ID: 812, Вес: 0.0339)
#   - Goofy Movie, A (1995) (ID: 239, Вес: 0.0334)
#   - Barcelona (1994) (ID: 417, Вес: 0.0321)
#   - George of the Jungle (1997) (ID: 1588, Вес: 0.0319)
#   - Frank and Ollie (1995) (ID: 398, Вес: 0.0318)
# Фильм: Gigi (1958) (ID: 938)
# Фильмы, влияющие на рекомендацию:
#   - Liebelei (1933) (ID: 894, Вес: 0.1307)
#   - Craft, The (1996) (ID: 724, Вес: 0.0482)
#   - This World, Then the Fireworks (1996) (ID: 2008, Вес: 0.0473)
#   - Maximum Overdrive (1986) (ID: 2119, Вес: 0.0415)
#   - Ninotchka (1939) (ID: 936, Вес: 0.0409)
#   - For Whom the Bell Tolls (1943) (ID: 897, Вес: 0.0396)
#   - Неизвестный фильм (ID: 1700, Вес: 0.0372)
#   - Robert A. Heinlein's The Puppet Masters (1994) (ID: 512, Вес: 0.0360)
#   - Machine, The (1994) (ID: 1433, Вес: 0.0359)
#   - Say Anything... (1989) (ID: 2248, Вес: 0.0353)
# Фильм: Seven (Se7en) (1995) (ID: 47)
# Фильмы, влияющие на рекомендацию:
#   - Magic Hunter (1994) (ID: 812, Вес: 0.1812)
#   - Farinelli: il castrato (1994) (ID: 242, Вес: 0.1450)
#   - 12 Angry Men (1957) (ID: 1203, Вес: 0.1364)
#   - Poetic Justice (1993) (ID: 510, Вес: 0.1142)
#   - Men With Guns (1997) (ID: 1788, Вес: 0.0898)
#   - Little Princess, A (1995) (ID: 262, Вес: 0.0760)
#   - Mr. Wonderful (1993) (ID: 499, Вес: 0.0587)
#   - Blackbeard's Ghost (1968) (ID: 2035, Вес: 0.0568)
#   - Goofy Movie, A (1995) (ID: 239, Вес: 0.0401)
#   - Gentleman's Agreement (1947) (ID: 1940, Вес: 0.0384)
# Фильм: 39 Steps, The (1935) (ID: 965)
# Фильмы, влияющие на рекомендацию:
#   - Normal Life (1996) (ID: 1053, Вес: 0.0954)
#   - Singin' in the Rain (1952) (ID: 899, Вес: 0.0703)
#   - Story of Xinghua, The (1993) (ID: 844, Вес: 0.0583)
#   - Something to Sing About (1937) (ID: 975, Вес: 0.0540)
#   - Who's Afraid of Virginia Woolf? (1966) (ID: 2132, Вес: 0.0537)
#   - Ninotchka (1939) (ID: 936, Вес: 0.0526)
#   - This World, Then the Fireworks (1996) (ID: 2008, Вес: 0.0526)
#   - It's My Party (1995) (ID: 685, Вес: 0.0488)
#   - Police Story 4: Project S (Chao ji ji hua) (1993) (ID: 876, Вес: 0.0486)
#   - They Made Me a Criminal (1939) (ID: 962, Вес: 0.0476)
# Фильм: Deep Impact (1998) (ID: 1876)
# Фильмы, влияющие на рекомендацию:
#   - Slums of Beverly Hills, The (1998) (ID: 2155, Вес: 0.0531)
#   - Clan of the Cave Bear, The (1986) (ID: 2147, Вес: 0.0528)
#   - Turning, The (1992) (ID: 1524, Вес: 0.0462)
#   - Неизвестный фильм (ID: 1736, Вес: 0.0348)
#   - Full Tilt Boogie (1997) (ID: 2061, Вес: 0.0347)
#   - Soul Man (1986) (ID: 2473, Вес: 0.0325)
#   - Hocus Pocus (1993) (ID: 2052, Вес: 0.0312)
#   - Hot Lead and Cold Feet (1978) (ID: 2055, Вес: 0.0309)
#   - Say Anything... (1989) (ID: 2248, Вес: 0.0305)
#   - Dadetown (1995) (ID: 1138, Вес: 0.0303)
# Рекомендации для пользователя 1557:
# Фильм: Georgia (1995) (ID: 55)
# Фильмы, влияющие на рекомендацию:
#   - Almost Heroes (1998) (ID: 1887, Вес: 0.0817)
#   - Carlito's Way (1993) (ID: 431, Вес: 0.0534)
#   - Peggy Sue Got Married (1986) (ID: 2469, Вес: 0.0524)
#   - Giant (1956) (ID: 948, Вес: 0.0520)
#   - Braindead (1992) (ID: 1241, Вес: 0.0470)
#   - Speechless (1994) (ID: 378, Вес: 0.0462)
#   - Flesh and Bone (1993) (ID: 451, Вес: 0.0446)
#   - Mrs. Dalloway (1997) (ID: 1684, Вес: 0.0405)
#   - King Kong vs. Godzilla (Kingukongu tai Gojira) (1962) (ID: 2365, Вес: 0.0369)
#   - Tough Guys (1986) (ID: 2472, Вес: 0.0361)
# Фильм: Happiness Is in the Field (1995) (ID: 115)
# Фильмы, влияющие на рекомендацию:
#   - King Kong vs. Godzilla (Kingukongu tai Gojira) (1962) (ID: 2365, Вес: 0.0894)
#   - Bridge on the River Kwai, The (1957) (ID: 1250, Вес: 0.0839)
#   - Almost Heroes (1998) (ID: 1887, Вес: 0.0725)
#   - Bob Roberts (1992) (ID: 1171, Вес: 0.0692)
#   - Proprietor, The (1996) (ID: 1052, Вес: 0.0634)
#   - Flesh and Bone (1993) (ID: 451, Вес: 0.0566)
#   - Mrs. Dalloway (1997) (ID: 1684, Вес: 0.0511)
#   - Giant (1956) (ID: 948, Вес: 0.0465)
#   - Twelve Monkeys (1995) (ID: 32, Вес: 0.0463)
#   - Shining, The (1980) (ID: 1258, Вес: 0.0459)
# Фильм: Net, The (1995) (ID: 185)
# Фильмы, влияющие на рекомендацию:
#   - Speechless (1994) (ID: 378, Вес: 0.0437)
#   - Outbreak (1995) (ID: 292, Вес: 0.0394)
#   - Poetic Justice (1993) (ID: 510, Вес: 0.0348)
#   - Goodbye, Lover (1999) (ID: 2586, Вес: 0.0295)
#   - Full Speed (1996) (ID: 1724, Вес: 0.0275)
#   - King Kong Lives (1986) (ID: 2368, Вес: 0.0274)
#   - Неизвестный фильм (ID: 622, Вес: 0.0268)
#   - Mighty Morphin Power Rangers: The Movie (1995) (ID: 181, Вес: 0.0227)
#   - Billy Madison (1995) (ID: 216, Вес: 0.0221)
#   - Peggy Sue Got Married (1986) (ID: 2469, Вес: 0.0215)
# Фильм: Hellraiser: Bloodline (1996) (ID: 611)
# Фильмы, влияющие на рекомендацию:
#   - Carlito's Way (1993) (ID: 431, Вес: 0.0485)
#   - Braindead (1992) (ID: 1241, Вес: 0.0407)
#   - Ruthless People (1986) (ID: 2463, Вес: 0.0387)
#   - Mrs. Dalloway (1997) (ID: 1684, Вес: 0.0372)
#   - Bob Roberts (1992) (ID: 1171, Вес: 0.0330)
#   - Peggy Sue Got Married (1986) (ID: 2469, Вес: 0.0302)
#   - Tough Guys (1986) (ID: 2472, Вес: 0.0301)
#   - NeverEnding Story III, The (1994) (ID: 126, Вес: 0.0282)
#   - I Shot Andy Warhol (1996) (ID: 766, Вес: 0.0273)
#   - Hurricane Streets (1998) (ID: 1659, Вес: 0.0243)
# Фильм: Beautiful Girls (1996) (ID: 94)
# Фильмы, влияющие на рекомендацию:
#   - Double Team (1997) (ID: 1497, Вес: 0.1867)
#   - Brother Minister: The Assassination of Malcolm X (1994) (ID: 404, Вес: 0.1157)
#   - Fear of a Black Hat (1993) (ID: 449, Вес: 0.1071)
#   - Billy Madison (1995) (ID: 216, Вес: 0.1046)
#   - Dance with Me (1998) (ID: 2168, Вес: 0.0860)
#   - For Richer or Poorer (1997) (ID: 1703, Вес: 0.0778)
#   - Goodbye, Lover (1999) (ID: 2586, Вес: 0.0723)
#   - Anne Frank Remembered (1995) (ID: 116, Вес: 0.0688)
#   - Flesh and Bone (1993) (ID: 451, Вес: 0.0647)
#   - Say Anything... (1989) (ID: 2248, Вес: 0.0575)
# Рекомендации для пользователя 3922:
# Фильм: 12 Angry Men (1957) (ID: 1203)
# Фильмы, влияющие на рекомендацию:
#   - Mr. Wonderful (1993) (ID: 499, Вес: 0.1514)
#   - Farinelli: il castrato (1994) (ID: 242, Вес: 0.1401)
#   - Lost Horizon (1937) (ID: 944, Вес: 0.1142)
#   - Hostile Intentions (1994) (ID: 675, Вес: 0.1027)
#   - Magic Hunter (1994) (ID: 812, Вес: 0.1018)
#   - Foreign Correspondent (1940) (ID: 929, Вес: 0.0939)
#   - Twelfth Night (1996) (ID: 892, Вес: 0.0595)
#   - Men With Guns (1997) (ID: 1788, Вес: 0.0539)
#   - When a Man Loves a Woman (1994) (ID: 381, Вес: 0.0496)
#   - Doctor Zhivago (1965) (ID: 2067, Вес: 0.0489)
# Фильм: Jack and Sarah (1995) (ID: 638)
# Фильмы, влияющие на рекомендацию:
#   - American in Paris, An (1951) (ID: 900, Вес: 0.4943)
#   - Barbarella (1968) (ID: 674, Вес: 0.0875)
#   - Beautiful Thing (1996) (ID: 1046, Вес: 0.0812)
#   - Bulletproof (1996) (ID: 886, Вес: 0.0713)
#   - Twelfth Night (1996) (ID: 892, Вес: 0.0569)
#   - Zeus and Roxanne (1997) (ID: 1426, Вес: 0.0524)
#   - Broken Arrow (1996) (ID: 95, Вес: 0.0460)
#   - Nothing to Lose (1994) (ID: 875, Вес: 0.0439)
#   - Mighty Peking Man (Hsing hsing wang) (1977) (ID: 2602, Вес: 0.0397)
#   - Girls Town (1996) (ID: 877, Вес: 0.0395)
# Фильм: August (1996) (ID: 660)
# Фильмы, влияющие на рекомендацию:
#   - To Be or Not to Be (1942) (ID: 946, Вес: 0.0707)
#   - Flipper (1996) (ID: 711, Вес: 0.0616)
#   - Tarantella (1995) (ID: 672, Вес: 0.0584)
#   - Неизвестный фильм (ID: 689, Вес: 0.0576)
#   - Mrs. Winterbourne (1996) (ID: 691, Вес: 0.0553)
#   - Horseman on the Roof, The (Hussard sur le toit, Le) (1995) (ID: 715, Вес: 0.0533)
#   - James and the Giant Peach (1996) (ID: 661, Вес: 0.0532)
#   - Great White Hype, The (1996) (ID: 725, Вес: 0.0494)
#   - 2001: A Space Odyssey (1968) (ID: 924, Вес: 0.0361)
#   - Mulholland Falls (1996) (ID: 707, Вес: 0.0347)
# Фильм: Angel and the Badman (1947) (ID: 964)
# Фильмы, влияющие на рекомендацию:
#   - Zeus and Roxanne (1997) (ID: 1426, Вес: 0.0889)
#   - Angus (1995) (ID: 700, Вес: 0.0765)
#   - Tainted (1998) (ID: 1764, Вес: 0.0675)
#   - Reluctant Debutante, The (1958) (ID: 939, Вес: 0.0659)
#   - Trigger Effect, The (1996) (ID: 882, Вес: 0.0648)
#   - Without Limits (1998) (ID: 2237, Вес: 0.0579)
#   - Women, The (1939) (ID: 927, Вес: 0.0554)
#   - Beautiful Girls (1996) (ID: 94, Вес: 0.0491)
#   - Great White Hype, The (1996) (ID: 725, Вес: 0.0471)
#   - Doctor Zhivago (1965) (ID: 2067, Вес: 0.0466)
# Фильм: Mother Night (1996) (ID: 893)
# Фильмы, влияющие на рекомендацию:
#   - Beautiful Thing (1996) (ID: 1046, Вес: 0.1633)
#   - Little Princess, The (1939) (ID: 917, Вес: 0.1531)
#   - Nothing to Lose (1994) (ID: 875, Вес: 0.0875)
#   - What Happened Was... (1994) (ID: 496, Вес: 0.0685)
#   - Philadelphia Story, The (1940) (ID: 898, Вес: 0.0647)
#   - Trigger Effect, The (1996) (ID: 882, Вес: 0.0544)
#   - Great White Hype, The (1996) (ID: 725, Вес: 0.0449)
#   - Universal Soldier: The Return (1999) (ID: 2807, Вес: 0.0445)
#   - Gentleman's Agreement (1947) (ID: 1940, Вес: 0.0428)
#   - Salut cousin! (1996) (ID: 1467, Вес: 0.0415)
# Рекомендации для пользователя 1103:
# Фильм: Relic, The (1997) (ID: 879)
# Фильмы, влияющие на рекомендацию:
#   - Little Princess, The (1939) (ID: 917, Вес: 0.1749)
#   - Spirits of the Dead (Tre Passi nel Delirio) (1968) (ID: 775, Вес: 0.0830)
#   - Matilda (1996) (ID: 837, Вес: 0.0827)
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0820)
#   - Universal Soldier: The Return (1999) (ID: 2807, Вес: 0.0732)
#   - Funny Face (1957) (ID: 901, Вес: 0.0701)
#   - Nothing to Lose (1994) (ID: 875, Вес: 0.0658)
#   - Mortal Thoughts (1991) (ID: 2267, Вес: 0.0619)
#   - What Happened Was... (1994) (ID: 496, Вес: 0.0490)
#   - Larger Than Life (1996) (ID: 813, Вес: 0.0475)
# Фильм: Indecent Proposal (1993) (ID: 2269)
# Фильмы, влияющие на рекомендацию:
#   - Hot Lead and Cold Feet (1978) (ID: 2055, Вес: 0.0925)
#   - And Now for Something Completely Different (1971) (ID: 2788, Вес: 0.0685)
#   - Night of the Living Dead (1968) (ID: 968, Вес: 0.0679)
#   - Supercop (1992) (ID: 861, Вес: 0.0672)
#   - Fandango (1985) (ID: 2073, Вес: 0.0671)
#   - Foreign Correspondent (1940) (ID: 929, Вес: 0.0649)
#   - Red Violin, The (Le Violon rouge) (1998) (ID: 2686, Вес: 0.0575)
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0547)
#   - Rich and Strange (1932) (ID: 2215, Вес: 0.0537)
#   - Frighteners, The (1996) (ID: 799, Вес: 0.0521)
# Фильм: Who's Afraid of Virginia Woolf? (1966) (ID: 2132)
# Фильмы, влияющие на рекомендацию:
#   - Normal Life (1996) (ID: 1053, Вес: 0.1207)
#   - Ninotchka (1939) (ID: 936, Вес: 0.1206)
#   - It's a Wonderful Life (1946) (ID: 953, Вес: 0.0847)
#   - Story of Xinghua, The (1993) (ID: 844, Вес: 0.0843)
#   - And Now for Something Completely Different (1971) (ID: 2788, Вес: 0.0819)
#   - Bulletproof (1996) (ID: 886, Вес: 0.0753)
#   - Rear Window (1954) (ID: 904, Вес: 0.0725)
#   - Fear of a Black Hat (1993) (ID: 449, Вес: 0.0684)
#   - Little Princess, A (1995) (ID: 262, Вес: 0.0679)
#   - Maximum Overdrive (1986) (ID: 2119, Вес: 0.0657)
# Фильм: Band Wagon, The (1953) (ID: 935)
# Фильмы, влияющие на рекомендацию:
#   - Mummy, The (1932) (ID: 2633, Вес: 0.1008)
#   - Beautiful Thing (1996) (ID: 1046, Вес: 0.0904)
#   - Hot Lead and Cold Feet (1978) (ID: 2055, Вес: 0.0753)
#   - Girls Town (1996) (ID: 877, Вес: 0.0583)
#   - Larger Than Life (1996) (ID: 813, Вес: 0.0470)
#   - Spirits of the Dead (Tre Passi nel Delirio) (1968) (ID: 775, Вес: 0.0380)
#   - Maximum Overdrive (1986) (ID: 2119, Вес: 0.0379)
#   - Little Princess, The (1939) (ID: 917, Вес: 0.0373)
#   - Normal Life (1996) (ID: 1053, Вес: 0.0357)
#   - Night of the Living Dead (1968) (ID: 968, Вес: 0.0355)
# Фильм: Mother Night (1996) (ID: 893)
# Фильмы, влияющие на рекомендацию:
#   - Little Princess, The (1939) (ID: 917, Вес: 0.1526)
#   - Beautiful Thing (1996) (ID: 1046, Вес: 0.1329)
#   - Browning Version, The (1994) (ID: 211, Вес: 0.1040)
#   - Неизвестный фильм (ID: 686, Вес: 0.0994)
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0811)
#   - Nothing to Lose (1994) (ID: 875, Вес: 0.0524)
#   - What Happened Was... (1994) (ID: 496, Вес: 0.0498)
#   - Bogus (1996) (ID: 885, Вес: 0.0486)
#   - Spirits of the Dead (Tre Passi nel Delirio) (1968) (ID: 775, Вес: 0.0478)
#   - Mummy, The (1932) (ID: 2633, Вес: 0.0457)
# Рекомендации для пользователя 4622:
# Фильм: Die Hard (1988) (ID: 1036)
# Фильмы, влияющие на рекомендацию:
#   - Unhook the Stars (1996) (ID: 1038, Вес: 0.1661)
#   - Cinderella (1950) (ID: 1022, Вес: 0.1369)
#   - Matilda (1996) (ID: 837, Вес: 0.0939)
#   - Fox and the Hound, The (1981) (ID: 1033, Вес: 0.0926)
#   - Неизвестный фильм (ID: 1790, Вес: 0.0751)
#   - Little Princess, The (1939) (ID: 917, Вес: 0.0685)
#   - 1-900 (1994) (ID: 889, Вес: 0.0418)
#   - I Went Down (1997) (ID: 1910, Вес: 0.0409)
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0355)
#   - Last Time I Committed Suicide, The (1997) (ID: 1567, Вес: 0.0340)
# Фильм: Halloween (1978) (ID: 1982)
# Фильмы, влияющие на рекомендацию:
#   - 1-900 (1994) (ID: 889, Вес: 0.1630)
#   - Browning Version, The (1994) (ID: 211, Вес: 0.1601)
#   - Get Over It (1996) (ID: 1142, Вес: 0.0911)
#   - Cinderella (1950) (ID: 1022, Вес: 0.0897)
#   - Pinocchio (1940) (ID: 596, Вес: 0.0839)
#   - Last Time I Committed Suicide, The (1997) (ID: 1567, Вес: 0.0637)
#   - Неизвестный фильм (ID: 1790, Вес: 0.0630)
#   - Gentleman's Agreement (1947) (ID: 1940, Вес: 0.0586)
#   - Nothing to Lose (1994) (ID: 875, Вес: 0.0569)
#   - Say Anything... (1989) (ID: 2248, Вес: 0.0550)
# Фильм: Lawnmower Man, The (1992) (ID: 1037)
# Фильмы, влияющие на рекомендацию:
#   - Unhook the Stars (1996) (ID: 1038, Вес: 0.1519)
#   - Неизвестный фильм (ID: 1790, Вес: 0.1347)
#   - Cinderella (1950) (ID: 1022, Вес: 0.1271)
#   - Fox and the Hound, The (1981) (ID: 1033, Вес: 0.1220)
#   - Last Time I Committed Suicide, The (1997) (ID: 1567, Вес: 0.0695)
#   - Smilla's Sense of Snow (1997) (ID: 1480, Вес: 0.0476)
#   - Matilda (1996) (ID: 837, Вес: 0.0412)
#   - Wanted: Dead or Alive (1987) (ID: 2756, Вес: 0.0398)
#   - Child's Play 2 (1990) (ID: 1992, Вес: 0.0265)
#   - It Came from Beneath the Sea (1955) (ID: 2663, Вес: 0.0227)
# Фильм: Неизвестный фильм (ID: 686)
# Фильмы, влияющие на рекомендацию:
#   - Besieged (L' Assedio) (1998) (ID: 2630, Вес: 0.1039)
#   - Dangerous Minds (1995) (ID: 31, Вес: 0.0955)
#   - Bob Roberts (1992) (ID: 1171, Вес: 0.0816)
#   - Death in the Garden (Mort en ce jardin, La) (1956) (ID: 820, Вес: 0.0743)
#   - Matilda (1996) (ID: 837, Вес: 0.0706)
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0621)
#   - Browning Version, The (1994) (ID: 211, Вес: 0.0528)
#   - Adrenalin: Fear the Rush (1996) (ID: 1383, Вес: 0.0494)
#   - Maya Lin: A Strong Clear Vision (1994) (ID: 759, Вес: 0.0484)
#   - My Man Godfrey (1936) (ID: 947, Вес: 0.0481)
# Фильм: Toys (1992) (ID: 2253)
# Фильмы, влияющие на рекомендацию:
#   - Good Man in Africa, A (1994) (ID: 462, Вес: 0.0786)
#   - Last Time I Committed Suicide, The (1997) (ID: 1567, Вес: 0.0758)
#   - She's So Lovely (1997) (ID: 1600, Вес: 0.0711)
#   - Dangerous Minds (1995) (ID: 31, Вес: 0.0674)
#   - Неизвестный фильм (ID: 1618, Вес: 0.0576)
#   - Cement Garden, The (1993) (ID: 1437, Вес: 0.0553)
#   - Maya Lin: A Strong Clear Vision (1994) (ID: 759, Вес: 0.0429)
#   - Death in the Garden (Mort en ce jardin, La) (1956) (ID: 820, Вес: 0.0381)
#   - Little Princess, The (1939) (ID: 917, Вес: 0.0381)
#   - Universal Soldier: The Return (1999) (ID: 2807, Вес: 0.0315)

# %% [markdown]
# ##### Задание 4. До этого мы работали с рейтингами, но как обсуждалось на лекции, implicit ALS отлично работает и с implicit фидбэком. Давайте попробуем преобразовать наш датасет(трейн и тест) следующим образом
#
# 1. Бинаризуем все рейтинги(заменим любую интеракцию пользователя на 1)
# 2. Заменим на 1 только рейтинги 4 и 5, а рейтинг ниже 4 заменим на 0
# 3. Заменим на 1 только рейтинги 4 и 5, а рейтинг ниже 4 заменим на -1
# 4. Заменим на 1 только рейтинги 4 и 5, а рейтинг ниже 4 заменим на -1 и добавим сглаживание по времени. То есть чем дальше была интеракция от максимальной даты трейна, тем с меньшим весом мы будем ее учитывать(например можно интеракции за последний месяц брать в исходном виде, и с каждым месяцем в прошлое умножать их на какой-нибудь коэффициент меньший 1). Таким образом более старые интеракции пользователя будут вносить меньший вклад в его интересы
# 5. Придумайте свой вариант(опционально)
#
# Для каждой полученной матрицы обучите iALS и SVD и сравните их результаты между собой(преобразовывать нужно только обучающую выборку, тестовую оставляем неизменной)

# %%
def transform_ratings(df: pd.DataFrame, method: str) -> pd.DataFrame:
    if method == "binary_all":
        df['rating'] = 1
    elif method == "binary_4_5_zero":
        df['rating'] = np.where(df['rating'] >= 4, 1, 0)
    elif method == "binary_4_5_neg":
        df['rating'] = np.where(df['rating'] >= 4, 1, -1)
    elif method == "binary_4_5_neg_time_decay":
        df['rating'] = np.where(df['rating'] >= 4, 1, -1)
        max_date = df['datetime'].max()
        df['days_diff'] = (max_date - df['datetime']).dt.days
        decay_rate = 0.1
        df['rating'] *= np.exp(-decay_rate * df['days_diff'])
    return df

# %%
df_test_filtered = df_test[
    df_test['user_id'].isin(df_train['user_id'].unique()) &
    df_test['item_id'].isin(df_train['item_id'].unique())
]

methods = [
    "binary_all",
    "binary_4_5_zero",
    "binary_4_5_neg",
    "binary_4_5_neg_time_decay"
]

results = {}

for method in methods:
    print(f"Преобразование данных: {method}")

    df_train_transformed = transform_ratings(df_train.copy(), method)
    coo_interactions_transformed = df_to_coo(df_train_transformed)

    als_recommendations, als_model = make_als_recommendations(
        coo_interactions_transformed,
        top_k=100,
        n_factors=100,
        alpha=1.0,
        regularization=0.01)

    svd_recommendations = make_svd_recommendations(
        coo_interactions_transformed,
        n_singular_values=10,
        top_k=100)

    als_ndcg = calculate_ndcg(df_test_filtered, als_recommendations, top_k=100)
    svd_ndcg = calculate_ndcg(df_test_filtered, svd_recommendations, top_k=100)

    results[method] = {"ALS NDCG": als_ndcg, "SVD NDCG": svd_ndcg}

for method, metrics in results.items():
    print(f"Метод: {method}")
    print(f"ALS NDCG: {metrics['ALS NDCG']}")
    print(f"SVD NDCG: {metrics['SVD NDCG']}")
# Out:
# Преобразование данных: binary_all
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.06662726402282715 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]
# Преобразование данных: binary_4_5_zero
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.04592108726501465 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]
# Преобразование данных: binary_4_5_neg
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.046607017517089844 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]
# Преобразование данных: binary_4_5_neg_time_decay
# /usr/local/lib/python3.11/dist-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_array instead. Converting to CSR took 0.03893780708312988 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]
# Метод: binary_all
# ALS NDCG: 0.47630145186541645
# SVD NDCG: 0.5022227216385845
# Метод: binary_4_5_zero
# ALS NDCG: 0.3971804820576986
# SVD NDCG: 0.4811894891772174
# Метод: binary_4_5_neg
# ALS NDCG: 0.4796527795060373
# SVD NDCG: 0.5020131154203998
# Метод: binary_4_5_neg_time_decay
# ALS NDCG: 0.4804716771117899
# SVD NDCG: 0.4766919718089815

# %% [markdown]
# ##### Задание 5. iALS на numpy/torch. Давайте реализуем алгоритм iALS на нумпае или торче. Требуется реализовать алгорит, описанный в 4 части [статьи](http://yifanhu.net/PUB/cf.pdf). Обратите внимания на все оптимизации, которые они описывают в статье, чтобы сократить лишние вычисления. Hint: метрики у вашего алгоритма должны быть сравнимы с метриками ALS из библиотеки implicit

# %%
class iALS:
    def __init__(self, n_factors: int = 100, alpha: float = 1.0, reg_coef: float = 0.01):

        self.n_factors = n_factors
        self.alpha = alpha
        self.reg_coef = reg_coef
        self.user_factors = None
        self.item_factors = None

    def fit(self, interactions: np.ndarray, n_iterations: int = 10):

        n_users, n_items = interactions.shape

        self.user_factors = np.random.rand(n_users, self.n_factors) * 0.01
        self.item_factors = np.random.rand(n_items, self.n_factors) * 0.01

        binary_interactions = (interactions > 0).astype(float)
        weighted_interactions = 1 + self.alpha * interactions

        for iteration in range(n_iterations):
            print(f"Iteration {iteration + 1}/{n_iterations}")

            for u in range(n_users):
                items_u = np.where(binary_interactions[u] > 0)[0]
                if len(items_u) == 0:
                    continue

                A_u = np.dot(self.item_factors[items_u].T, self.item_factors[items_u] * weighted_interactions[u, items_u][:, np.newaxis])
                A_u += self.reg_coef * np.eye(self.n_factors)
                b_u = np.dot(self.item_factors[items_u].T, weighted_interactions[u, items_u])

                self.user_factors[u] = np.linalg.solve(A_u, b_u)

            for i in range(n_items):
                users_i = np.where(binary_interactions[:, i] > 0)[0]
                if len(users_i) == 0:
                    continue

                A_i = np.dot(self.user_factors[users_i].T, self.user_factors[users_i] * weighted_interactions[users_i, i][:, np.newaxis])
                A_i += self.reg_coef * np.eye(self.n_factors)
                b_i = np.dot(self.user_factors[users_i].T, weighted_interactions[users_i, i])

                self.item_factors[i] = np.linalg.solve(A_i, b_i)

    def predict(self, top_k: int = 100):
        n_users = self.user_factors.shape[0]
        predicted_scores = np.dot(self.user_factors, self.item_factors.T)
        predicted_scores[predicted_scores == 0] = -np.inf
        predicts = np.argsort(-predicted_scores, axis=1)[:, :top_k]

        return predicts

# %%
ials = iALS(n_factors=100, alpha=1.0, reg_coef=0.01)
ials.fit(interactions, n_iterations=10)
recommendations_custom = ials.predict(top_k=10)

ndcg_custom = calculate_ndcg(df_test, recommendations_custom, top_k=100)

print(f"NDCG: {ndcg_custom}")
# Out:
# Iteration 1/10
# Iteration 2/10
# Iteration 3/10
# Iteration 4/10
# Iteration 5/10
# Iteration 6/10
# Iteration 7/10
# Iteration 8/10
# Iteration 9/10
# Iteration 10/10
# NDCG: 0.1228809764703263
